# %% [markdown]
# # Analysis 1: Plot a bar chart using matplotlib that represents each Borough(Counties) against the number of motorist injured for the multivariant conditions icluding that VEHICLE TYPE CODE 1 = PASSENGER VEHICLE and NUMBER OF MOTORIST KILLED = 1.

# %%
import matplotlib.pyplot as plt
import glob
import random
import numpy as np
import pandas as pd
import seaborn as sns
files='C:/Users/Shailesh Hegde/Desktop/PythonFinal/Accident_analysis.csv'
df1 =pd.read_csv(files)
        
#print(df_new)
print(df1.loc[(df1['VEHICLE TYPE CODE 1'] == 'PASSENGER VEHICLE') & (df1['NUMBER OF MOTORIST KILLED'] == 1)])
df_new=df1.loc[(df1['VEHICLE TYPE CODE 1'] == 'PASSENGER VEHICLE') & (df1['NUMBER OF MOTORIST KILLED'] == 1)]
df_new.plot.bar(x='BOROUGH', y='NUMBER OF MOTORIST INJURED')
print('here')
plt.show()
# Out:
#              DATE   TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2648    12/1/2015  18:14  BROOKLYN     11235  40.583900 -73.938739
# 9207    3/26/2016  21:06     BRONX     10467  40.865508 -73.863521
# 26137  11/20/2014  12:45    QUEENS     11434  40.687023 -73.765947
# 30409   8/17/2014   4:14  BROOKLYN     11213  40.669100 -73.936657
# 40504  12/31/2013  14:42    QUEENS     11358  40.767223 -73.793614
# 45620  10/22/2013   4:30  BROOKLYN     11236  40.640239 -73.919461
# 52952    9/5/2014  13:49  BROOKLYN     11209  40.618500 -74.039576
# 53493   7/24/2014   2:19     BRONX     10468  40.871005 -73.893839
# 58828  11/18/2012   2:47    QUEENS     11411  40.698357 -73.731358
# 65194    1/6/2013  21:12  BROOKLYN     11203  40.655884 -73.942400
# 66661  11/14/2012   5:48  BROOKLYN     11233  40.676938 -73.921825
# 68776   9/17/2012  20:31  BROOKLYN     11230  40.626841 -73.968478
# 71312   6/28/2015   4:35     BRONX     10463  40.877221 -73.909045
# 75388    4/8/2014   4:47  BROOKLYN     11236  40.641729 -73.907636
# 75609  11/30/2014  17:20  BROOKLYN     11205  40.697761 -73.968740
# 76720   8/31/2012  14:40     BRONX     10466  40.899815 -73.857804
#
#                         LOCATION      ON STREET NAME CROSS STREET NAME  \
# 2648   (40.5839003, -73.9387393)       EMMONS AVENUE   NOSTRAND AVENUE
# 9207   (40.8655081, -73.8635212)     ALLERTON AVENUE     BARNES AVENUE
# 26137  (40.6870226, -73.7659469)            119 ROAD         178 PLACE
# 30409  (40.6691002, -73.9366568)     EASTERN PARKWAY       TROY AVENUE
# 40504  (40.7672226, -73.7936144)          172 STREET         33 AVENUE
# 45620   (40.640239, -73.9194608)        RALPH AVENUE     FOSTER AVENUE
# 52952  (40.6184997, -74.0395757)          SHORE ROAD         93 STREET
# 53493  (40.8710047, -73.8938386)       JEROME AVENUE     MORRIS AVENUE
# 58828   (40.6983571, -73.731358)          227 STREET        115 AVENUE
# 65194  (40.6558844, -73.9423998)     CLARKSON AVENUE    EAST 38 STREET
# 66661  (40.6769384, -73.9218247)     ATLANTIC AVENUE      RALPH AVENUE
# 68776  (40.6268409, -73.9684781)            AVENUE I     EAST 8 STREET
# 71312  (40.8772207, -73.9090451)  MARBLE HILL AVENUE   WEST 228 STREET
# 75388  (40.6417288, -73.9076365)       REMSEN AVENUE     GLENWOOD ROAD
# 75609  (40.6977606, -73.9687403)     FLUSHING AVENUE    WAVERLY AVENUE
# 76720  (40.8998154, -73.8578041)       NEREID AVENUE   BRONX BOULEVARD
#
#        OFF STREET NAME         ...           CONTRIBUTING FACTOR VEHICLE 2  \
# 2648               NaN         ...             Traffic Control Disregarded
# 9207               NaN         ...             Traffic Control Disregarded
# 26137              NaN         ...             Traffic Control Disregarded
# 30409              NaN         ...                     Alcohol Involvement
# 40504              NaN         ...                     Physical Disability
# 45620              NaN         ...                         Other Vehicular
# 52952              NaN         ...             Traffic Control Disregarded
# 53493              NaN         ...          Driver Inattention/Distraction
# 58828              NaN         ...                     Alcohol Involvement
# 65194              NaN         ...                      Lost Consciousness
# 66661              NaN         ...           Failure to Yield Right-of-Way
# 68776              NaN         ...          Driver Inattention/Distraction
# 71312              NaN         ...          Driver Inattention/Distraction
# 75388              NaN         ...             Traffic Control Disregarded
# 75609              NaN         ...          Driver Inattention/Distraction
# 76720              NaN         ...                 Prescription Medication
#
#         CONTRIBUTING FACTOR VEHICLE 3   CONTRIBUTING FACTOR VEHICLE 4  \
# 2648                      Unspecified                             NaN
# 9207      Traffic Control Disregarded                             NaN
# 26137                             NaN                             NaN
# 30409                     Unspecified                             NaN
# 40504                     Unspecified                             NaN
# 45620                 Other Vehicular                             NaN
# 52952                             NaN                             NaN
# 53493                     Unspecified                     Unspecified
# 58828     Traffic Control Disregarded                     Unspecified
# 65194                             NaN                             NaN
# 66661                             NaN                             NaN
# 68776                             NaN                             NaN
# 71312  Driver Inattention/Distraction  Driver Inattention/Distraction
# 75388                     Unspecified                     Unspecified
# 75609                             NaN                             NaN
# 76720                             NaN                             NaN
#
#        CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  VEHICLE TYPE CODE 1  \
# 2648                             NaN     3344557    PASSENGER VEHICLE
# 9207                             NaN     3413870    PASSENGER VEHICLE
# 26137                            NaN     2827222    PASSENGER VEHICLE
# 30409                            NaN     1009830    PASSENGER VEHICLE
# 40504                            NaN      253861    PASSENGER VEHICLE
# 45620                            NaN      128796    PASSENGER VEHICLE
# 52952                            NaN     1019091    PASSENGER VEHICLE
# 53493                            NaN      997906    PASSENGER VEHICLE
# 58828                            NaN      221299    PASSENGER VEHICLE
# 65194                            NaN      153400    PASSENGER VEHICLE
# 66661                            NaN      160830    PASSENGER VEHICLE
# 68776                            NaN      130513    PASSENGER VEHICLE
# 71312                            NaN     3248243    PASSENGER VEHICLE
# 75388                            NaN      317135    PASSENGER VEHICLE
# 75609                            NaN     3128360    PASSENGER VEHICLE
# 76720                            NaN       95407    PASSENGER VEHICLE
#
#        VEHICLE TYPE CODE 2             VEHICLE TYPE CODE 3  \
# 2648     PASSENGER VEHICLE                   PICK-UP TRUCK
# 9207     PASSENGER VEHICLE               PASSENGER VEHICLE
# 26137           MOTORCYCLE                             NaN
# 30409    PASSENGER VEHICLE               PASSENGER VEHICLE
# 40504    PASSENGER VEHICLE               PASSENGER VEHICLE
# 45620    PASSENGER VEHICLE  LARGE COM VEH(6 OR MORE TIRES)
# 52952           MOTORCYCLE                             NaN
# 53493    PASSENGER VEHICLE               PASSENGER VEHICLE
# 58828    PASSENGER VEHICLE               PASSENGER VEHICLE
# 65194           MOTORCYCLE                             NaN
# 66661    PASSENGER VEHICLE                             NaN
# 68776    PASSENGER VEHICLE                             NaN
# 71312    PASSENGER VEHICLE               PASSENGER VEHICLE
# 75388    PASSENGER VEHICLE               PASSENGER VEHICLE
# 75609           MOTORCYCLE                             NaN
# 76720    PASSENGER VEHICLE                             NaN
#
#       VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 2648                  NaN                 NaN
# 9207                  NaN                 NaN
# 26137                 NaN                 NaN
# 30409                 NaN                 NaN
# 40504                 NaN                 NaN
# 45620                 NaN                 NaN
# 52952                 NaN                 NaN
# 53493   PASSENGER VEHICLE                 NaN
# 58828   PASSENGER VEHICLE                 NaN
# 65194                 NaN                 NaN
# 66661                 NaN                 NaN
# 68776                 NaN                 NaN
# 71312   PASSENGER VEHICLE                 NaN
# 75388   PASSENGER VEHICLE   PASSENGER VEHICLE
# 75609                 NaN                 NaN
# 76720                 NaN                 NaN
#
# [16 rows x 29 columns]
# here

# %% [markdown]
# # Analysis 2 (Find out how the number of persons injured has stacked up every year from 2012 to 2016)

# %%
import matplotlib.pyplot as plt
import glob
import random
import numpy as np
import pandas as pd
import seaborn as sns
files='C:/Users/Shailesh Hegde/Desktop/PythonFinal/Accident_analysis.csv'
df1 =pd.read_csv(files)
        
df1["DATE"] = pd.to_datetime(df1["DATE"])
df1["DATE"].dt.year
df1.groupby([df1["DATE"].dt.year]).sum()
#df_new = df1.groupby([df1["DATE"].dt.year]).sum()
print(df1)
df1.reset_index(drop=True)
df1.plot.line(x='DATE', y=['NUMBER OF MOTORIST INJURED','NUMBER OF PEDESTRIANS INJURED'])

print('here')
plt.show()
# Out:
#             DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     2016-03-14  21:15  MANHATTAN     10013  40.726436 -74.005657
# 1     2016-11-10   6:11  MANHATTAN     10037  40.814673 -73.936211
# 2     2016-03-14  21:19   BROOKLYN     11226  40.647870 -73.955737
# 3     2016-11-10  17:11   BROOKLYN     11236  40.640000 -73.901931
# 4     2016-11-10  17:11  MANHATTAN     10036  40.759406 -73.985103
# 5     2016-03-14  21:25     QUEENS     11377  40.745596 -73.903389
# 6     2016-03-14  21:29  MANHATTAN     10022  40.764898 -73.972553
# 7     2016-03-14  22:10  MANHATTAN     10022  40.761234 -73.963884
# 8     2016-03-14  22:10     QUEENS     11355  40.752006 -73.809835
# 9     2016-03-14  22:15  MANHATTAN     10038  40.713468 -73.998582
# 10    2016-03-14  22:45     QUEENS     11420  40.671027 -73.812986
# 11    2016-03-14  22:55   BROOKLYN     11230  40.633111 -73.972161
# 12    2016-03-14  23:00     QUEENS     11101  40.748916 -73.937396
# 13    2016-03-14   3:30  MANHATTAN     10021  40.768119 -73.958862
# 14    2016-03-14   3:45   BROOKLYN     11213  40.671034 -73.939261
# 81578  (40.7556754, -73.7287085)           MARATHON PARKWAY
# 81579  (40.7805613, -73.9802091)             WEST 75 STREET
# 81580  (40.7548409, -73.9841185)                   6 AVENUE
# 81581   (40.694578, -73.9561419)             BEDFORD AVENUE
# 81582  (40.7460781, -73.9749359)             EAST 36 STREET
# 81583  (40.7384884, -73.9899502)             EAST 19 STREET
# 81584  (40.7509597, -73.9827227)             WEST 38 STREET
# 81585  (40.7852936, -73.9693348)          CENTRAL PARK WEST
# 81586  (40.8316829, -73.8271113)        EAST TREMONT AVENUE
# 81587   (40.6566425, -74.005262)                  34 STREET
# 81588  (40.7661449, -73.9972347)             WEST 49 STREET
# 81589  (40.7691197, -73.9550386)             EAST 74 STREET
# 81590  (40.8703607, -73.9044192)      WEST KINGSBRIDGE ROAD
#
#              CROSS STREET NAME  OFF STREET NAME         ...          \
# 0                VANDAM STREET              NaN         ...
# 1                     5 AVENUE              NaN         ...
# 2               BEDFORD AVENUE              NaN         ...
# 3               EAST 93 STREET              NaN         ...
# 4                     BROADWAY              NaN         ...
# 5             ROOSEVELT AVENUE              NaN         ...
# 6                     5 AVENUE              NaN         ...
# 7               EAST 60 STREET              NaN         ...
# 8              LABURNUM AVENUE              NaN         ...
# 9               CHATHAM SQUARE              NaN         ...
# 10                  126 STREET              NaN         ...
# 11               OCEAN PARKWAY              NaN         ...
# 12              JACKSON AVENUE              NaN         ...
# 13                    2 AVENUE              NaN         ...
# 14               ALBANY AVENUE              NaN         ...
# 15              EAST 50 STREET              NaN         ...
# 16             SARATOGA AVENUE              NaN         ...
# 17                   34 AVENUE              NaN         ...
# 18               REEVES AVENUE              NaN         ...
# 19               BASCOM AVENUE              NaN         ...
# 20                   65 STREET              NaN         ...
# 21              EAST 53 STREET              NaN         ...
# 22                CROWN STREET              NaN         ...
# 23            LAFAYETTE AVENUE              NaN         ...
# 24                 DEAN STREET              NaN         ...
# 25             NOSTRAND AVENUE              NaN         ...
# 26              EAST 42 STREET              NaN         ...
# 27       FORT HAMILTON PARKWAY              NaN         ...
# 28              BUSSING AVENUE              NaN         ...
# 29               IRVING AVENUE              NaN         ...
# ...                        ...              ...         ...
# 81561            MYRTLE AVENUE              NaN         ...
# 81562           EAST 63 STREET              NaN         ...
# 81563                 BROADWAY              NaN         ...
# 81564               104 AVENUE              NaN         ...
# 81565               107 STREET              NaN         ...
# 81566          SEDGWICK AVENUE              NaN         ...
# 81567                 5 AVENUE              NaN         ...
# 81568        WEST SIDE HIGHWAY              NaN         ...
# 81569            VERNON AVENUE              NaN         ...
# 81570            CROSBY STREET              NaN         ...
# 81571                 3 AVENUE              NaN         ...
# 81572           WEST 97 STREET              NaN         ...
# 81573          WEST END AVENUE              NaN         ...
# 81574                 7 AVENUE              NaN         ...
# 81575            BROOME STREET              NaN         ...
# 81576              WEST STREET              NaN         ...
# 81577  CORPORAL KENNEDY STREET              NaN         ...
# 81578                63 AVENUE              NaN         ...
# 81579         AMSTERDAM AVENUE              NaN         ...
# 81580           WEST 42 STREET              NaN         ...
# 81581            MYRTLE AVENUE              NaN         ...
# 81582                 2 AVENUE              NaN         ...
# 81583                 BROADWAY              NaN         ...
# 81584                 5 AVENUE              NaN         ...
# 81585           WEST 86 STREET              NaN         ...
# 81586             GREENE PLACE              NaN         ...
# 81587                 3 AVENUE              NaN         ...
# 81588        WEST SIDE HIGHWAY              NaN         ...
# 81589                 1 AVENUE              NaN         ...
# 81590      KINGSBRIDGE TERRACE              NaN         ...
#
#         CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                 Driver Inexperience                            NaN
# 1                     Other Vehicular                            NaN
# 2               Passenger Distraction                            NaN
# 3      Driver Inattention/Distraction                    Unspecified
# 4                     Other Vehicular                            NaN
# 5                    Backing Unsafely                            NaN
# 6      Driver Inattention/Distraction                            NaN
# 7      Driver Inattention/Distraction                            NaN
# 8         Traffic Control Disregarded                            NaN
# 9                    Backing Unsafely                            NaN
# 10                    Fatigued/Drowsy                            NaN
# 11     Driver Inattention/Distraction                            NaN
# 12                 Lost Consciousness                            NaN
# 13                Alcohol Involvement            Alcohol Involvement
# 14                  Pavement Slippery              Pavement Slippery
# 15     Driver Inattention/Distraction                            NaN
# 16            Outside Car Distraction                            NaN
# 17                Physical Disability            Physical Disability
# 18               Unsafe Lane Changing                            NaN
# 19     Driver Inattention/Distraction                    Unspecified
# 20                 Lost Consciousness                            NaN
# 21                    Other Vehicular                            NaN
# 22                 Lost Consciousness                            NaN
# 23      Failure to Yield Right-of-Way                            NaN
# 24                    Fatigued/Drowsy                            NaN
# 25                    Fatigued/Drowsy                            NaN
# 26     Driver Inattention/Distraction                            NaN
# 27     Driver Inattention/Distraction                            NaN
# 28      Failure to Yield Right-of-Way                            NaN
# 29              Passenger Distraction                            NaN
# ...                               ...                            ...
# 81561                Backing Unsafely                            NaN
# 81562                 Other Vehicular                            NaN
# 81563                 Fatigued/Drowsy                            NaN
# 81564  Driver Inattention/Distraction                            NaN
# 81565   Failure to Yield Right-of-Way                            NaN
# 81566              Pavement Defective                            NaN
# 81567                 Other Vehicular                            NaN
# 81568              Lost Consciousness                            NaN
# 81569              Lost Consciousness                            NaN
# 81570           Passenger Distraction                            NaN
# 81571                 Other Vehicular                            NaN
# 81572     Traffic Control Disregarded                            NaN
# 81573                 Other Vehicular                            NaN
# 81574                 Fatigued/Drowsy                            NaN
# 81575              Turning Improperly                            NaN
# 81576              Lost Consciousness                            NaN
# 81577              Turning Improperly                            NaN
# 81578                Backing Unsafely                            NaN
# 81579                 Other Vehicular                            NaN
# 81580                 Other Vehicular                            NaN
# 81581                 Fatigued/Drowsy                    Unspecified
# 81582                 Other Vehicular                            NaN
# 81583  Driver Inattention/Distraction                            NaN
# 81584              Turning Improperly                            NaN
# 81585         Prescription Medication                    Unspecified
# 81586  Driver Inattention/Distraction                            NaN
# 81587   Failure to Yield Right-of-Way                            NaN
# 81588  Driver Inattention/Distraction                            NaN
# 81589                 Other Vehicular                            NaN
# 81590                 Other Vehicular                            NaN
#
#        CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# 81566       87453              PASSENGER VEHICLE
# 81567       45741              PASSENGER VEHICLE
# 81568       38354  SPORT UTILITY / STATION WAGON
# 81569     3291792              PASSENGER VEHICLE
# 81570        5613                           TAXI
# 81571       45340                            VAN
# 81572       57693                           TAXI
# 81573     3345153              PASSENGER VEHICLE
# 81574       26169                           TAXI
# 81575     3341870                            BUS
# 81576     3362787  SPORT UTILITY / STATION WAGON
# 81577     3242624              PASSENGER VEHICLE
# 81578     3242118  SPORT UTILITY / STATION WAGON
# 81579     3243390                            VAN
# 81580     3239736                          OTHER
# 81581     3238145              PASSENGER VEHICLE
# 81582     3230767                 LIVERY VEHICLE
# 81583     3226464                        UNKNOWN
# 81584     3220963                           TAXI
# 81585     3220383  SPORT UTILITY / STATION WAGON
# 81586     3220462  SPORT UTILITY / STATION WAGON
# 81587      157121                            BUS
# 81588       39710                            VAN
# 81589       46486                  PICK-UP TRUCK
# 81590      107008              PASSENGER VEHICLE
#
#                   VEHICLE TYPE CODE 2            VEHICLE TYPE CODE 3  \
# 0                   PASSENGER VEHICLE                            NaN
# 1                                 NaN                            NaN
# 2                             BICYCLE                            NaN
# 3       SPORT UTILITY / STATION WAGON              PASSENGER VEHICLE
# 4       SPORT UTILITY / STATION WAGON                            NaN
# 5                   PASSENGER VEHICLE                            NaN
# 6                   PASSENGER VEHICLE                            NaN
# 7                   PASSENGER VEHICLE                            NaN
# 8                   PASSENGER VEHICLE                            NaN
# 9                   PASSENGER VEHICLE                            NaN
# 10                  PASSENGER VEHICLE                            NaN
# 11                            BICYCLE                            NaN
# 12                                NaN                            NaN
# 13                  PASSENGER VEHICLE              PASSENGER VEHICLE
# 14                  PASSENGER VEHICLE              PASSENGER VEHICLE
# 15                                NaN                            NaN
# 16                  PASSENGER VEHICLE                            NaN
# 17                  PASSENGER VEHICLE              PASSENGER VEHICLE
# 18                  PASSENGER VEHICLE                            NaN
# 19      SPORT UTILITY / STATION WAGON  SPORT UTILITY / STATION WAGON
# 20     LARGE COM VEH(6 OR MORE TIRES)                            NaN
# 21                              OTHER                            NaN
# 22                  PASSENGER VEHICLE                            NaN
# 23                            BICYCLE                            NaN
# 24                  PASSENGER VEHICLE                            NaN
# 25                  PASSENGER VEHICLE                            NaN
# 26                  PASSENGER VEHICLE                            NaN
# 27                                NaN                            NaN
# 28                  PASSENGER VEHICLE                            NaN
# 29                            BICYCLE                            NaN
# ...                               ...                            ...
# 81561   SPORT UTILITY / STATION WAGON                            NaN
# 81562                         UNKNOWN                            NaN
# 81563               PASSENGER VEHICLE                            NaN
# 81564                             BUS                            NaN
# 81565               PASSENGER VEHICLE                            NaN
# 81566               PASSENGER VEHICLE                            NaN
# 81567   SPORT UTILITY / STATION WAGON                            NaN
# 81568               PASSENGER VEHICLE                            NaN
# 81569                         BICYCLE                            NaN
# 81570                         BICYCLE                            NaN
# 81571                           OTHER                            NaN
# 81572                            TAXI                            NaN
# 81573               PASSENGER VEHICLE                            NaN
# 81574               PASSENGER VEHICLE                            NaN
# 81575   SPORT UTILITY / STATION WAGON                            NaN
# 81576               PASSENGER VEHICLE                            NaN
# 81577               PASSENGER VEHICLE                            NaN
# 81578               PASSENGER VEHICLE                            NaN
# 81579   SPORT UTILITY / STATION WAGON                            NaN
# 81580                           OTHER                            NaN
# 81581   SPORT UTILITY / STATION WAGON                            VAN
# 81582               PASSENGER VEHICLE                            NaN
# 81583                         UNKNOWN                            NaN
# 81584                             BUS                            NaN
# 81585   SPORT UTILITY / STATION WAGON  SPORT UTILITY / STATION WAGON
# 81586               PASSENGER VEHICLE                            NaN
# 81587          SMALL COM VEH(4 TIRES)                            NaN
# 81588          SMALL COM VEH(4 TIRES)                            NaN
# 81589   SPORT UTILITY / STATION WAGON                            NaN
# 81590   SPORT UTILITY / STATION WAGON                            NaN
#
#       VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4                     NaN                 NaN
# 5                     NaN                 NaN
# 6                     NaN                 NaN
# 7                     NaN                 NaN
# 8                     NaN                 NaN
# 9                     NaN                 NaN
# 10                    NaN                 NaN
# 11                    NaN                 NaN
# 12                    NaN                 NaN
# 13                    NaN                 NaN
# 14                    NaN                 NaN
# 15                    NaN                 NaN
# 16                    NaN                 NaN
# 17                    NaN                 NaN
# 18                    NaN                 NaN
# 19                    NaN                 NaN
# 20                    NaN                 NaN
# 21                    NaN                 NaN
# 22                    NaN                 NaN
# 23                    NaN                 NaN
# 24                    NaN                 NaN
# 25                    NaN                 NaN
# 26                    NaN                 NaN
# 27                    NaN                 NaN
# 28                    NaN                 NaN
# 29                    NaN                 NaN
# ...                   ...                 ...
# 81561                 NaN                 NaN
# 81562                 NaN                 NaN
# 81563                 NaN                 NaN
# 81564                 NaN                 NaN
# 81565                 NaN                 NaN
# 81566                 NaN                 NaN
# 81567                 NaN                 NaN
# 81568                 NaN                 NaN
# 81569                 NaN                 NaN
# 81570                 NaN                 NaN
# 81571                 NaN                 NaN
# 81572                 NaN                 NaN
# 81573                 NaN                 NaN
# 81574                 NaN                 NaN
# 81575                 NaN                 NaN
# 81576                 NaN                 NaN
# 81577                 NaN                 NaN
# 81578                 NaN                 NaN
# 81579                 NaN                 NaN
# 81580                 NaN                 NaN
# 81581                 NaN                 NaN
# 81582                 NaN                 NaN
# 81583                 NaN                 NaN
# 81584                 NaN                 NaN
# 81585                 NaN                 NaN
# 81586                 NaN                 NaN
# 81587                 NaN                 NaN
# 81588                 NaN                 NaN
# 81589                 NaN                 NaN
# 81590                 NaN                 NaN
#
# [81591 rows x 29 columns]
# here

# %% [markdown]
# # Analysis 3: Plot the number of motorists,persons and pedestrians injured for VEHICLE TYPE CODE 1 = PASSENGER VEHICLE using a line graph plot.

# %%
from matplotlib.pyplot import pie, axis, show
import matplotlib.pyplot as plt
import glob
import random
import numpy as np
import pandas as pd
import seaborn as sns
files='C:/Users/Shailesh Hegde/Desktop/PythonFinal/Accident_analysis.csv'
df1 =pd.read_csv(files)
        
df1["DATE"] = pd.to_datetime(df1["DATE"])
df1["DATE"].dt.year
df1.groupby(["VEHICLE TYPE CODE 1"]).sum()
df1.loc[(df1['VEHICLE TYPE CODE 1'] == 'PASSENGER VEHICLE')]
print(df1)
#print(df1.groupby(["VEHICLE TYPE CODE 1"]).sum())
#df_new = df1.groupby(["VEHICLE TYPE CODE 1"]).sum()
#print(df_new)
df1.plot.line(x='VEHICLE TYPE CODE 1', y=['NUMBER OF MOTORIST INJURED','NUMBER OF PEDESTRIANS INJURED','NUMBER OF PERSONS INJURED','NUMBER OF CYCLIST INJURED'])
print('here')
plt.show()
# Out:
#                                  ZIP CODE      LATITUDE     LONGITUDE  \
# VEHICLE TYPE CODE 1
# AMBULANCE                         2051693  7.947196e+03 -1.441720e+04
# BICYCLE                           1209846  4.601962e+03 -8.356406e+03
# BUS                              16712022  6.485661e+04 -1.177190e+05
# FIRE TRUCK                         477919  1.833433e+03 -3.326970e+03
# LARGE COM VEH(6 OR MORE TIRES)   15157186  5.895530e+04 -1.070082e+05
# LIVERY VEHICLE                   15830621  6.274528e+04 -1.138125e+05
# MOTORCYCLE                        3951857  1.511387e+04 -2.742915e+04
# OTHER                            21930255  8.453292e+04 -1.534292e+05
# PASSENGER VEHICLE               478776828  1.815569e+06 -3.295615e+06
# PEDICAB                             40136  1.630714e+02 -2.959028e+02
# PICK-UP TRUCK                    12333635  4.786757e+04 -8.688881e+04
# SCOOTER                            178674  6.929214e+02 -1.257139e+03
# SMALL COM VEH(4 TIRES)           16772262  6.543313e+04 -1.187711e+05
# SPORT UTILITY / STATION WAGON   180898437  6.864322e+05 -1.245929e+06
# TAXI                             61641325  2.476331e+05 -4.494411e+05
# UNKNOWN                          11578779  4.433918e+04 -8.043235e+04
# VAN                              28352821  1.102015e+05 -2.000230e+05
#
#                                 OFF STREET NAME  NUMBER OF PERSONS INJURED  \
# VEHICLE TYPE CODE 1
# AMBULANCE                                   NaN                         39
# BICYCLE                                     NaN                         85
# BUS                                         NaN                        242
# FIRE TRUCK                                  NaN                         15
# LARGE COM VEH(6 OR MORE TIRES)              NaN                        144
# LIVERY VEHICLE                              NaN                        374
# MOTORCYCLE                                  NaN                        196
# OTHER                                       NaN                        333
# PASSENGER VEHICLE                           NaN                      11348
# PEDICAB                                     NaN                          0
# PICK-UP TRUCK                               NaN                        187
# SCOOTER                                     NaN                         10
# SMALL COM VEH(4 TIRES)                      NaN                        212
# SPORT UTILITY / STATION WAGON               NaN                       3890
# TAXI                                        NaN                       1092
# UNKNOWN                                     NaN                        274
# VAN                                         NaN                        430
#
#                                 NUMBER OF PERSONS KILLED  \
# VEHICLE TYPE CODE 1
# AMBULANCE                                              0
# BICYCLE                                                1
# BUS                                                    0
# FIRE TRUCK                                             0
# LARGE COM VEH(6 OR MORE TIRES)                         2
# LIVERY VEHICLE                                         0
# MOTORCYCLE                                             6
# OTHER                                                  0
# PASSENGER VEHICLE                                     21
# PEDICAB                                                0
# PICK-UP TRUCK                                          0
# SCOOTER                                                0
# SMALL COM VEH(4 TIRES)                                 0
# SPORT UTILITY / STATION WAGON                          8
# TAXI                                                   1
# UNKNOWN                                                1
# VAN                                                    1
#
# VEHICLE TYPE CODE 1
# AMBULANCE                                               0    358079290
# BICYCLE                                                 0    319784805
# BUS                                                     0   2744728352
# FIRE TRUCK                                              0     87130962
# LARGE COM VEH(6 OR MORE TIRES)                          1   2559301395
# LIVERY VEHICLE                                          0   2813418419
# MOTORCYCLE                                              6    699569411
# OTHER                                                   0   4064860817
# PASSENGER VEHICLE                                      16  94534284344
# PEDICAB                                                 0      7141181
# PICK-UP TRUCK                                           0   2281981578
# SCOOTER                                                 0     21063073
# SMALL COM VEH(4 TIRES)                                  0   2886558445
# SPORT UTILITY / STATION WAGON                           2  32147905448
# TAXI                                                    0  10391202800
# UNKNOWN                                                 0   2082807208
# VAN                                                     0   4806197267
# here

# %% [markdown]
# # Analysis 4: lot a pie chart that represents 'NUMBER OF MOTORIST INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PERSONS INJURED', 'NUMBER OF CYCLIST INJURED' for the Borough=Brooklyn.

# %%
from matplotlib.pyplot import pie, axis, show
import matplotlib.pyplot as plt
import glob
import random
import numpy as np
import pandas as pd
import seaborn as sns
files='C:/Users/Shailesh Hegde/Desktop/PythonFinal/Accident_analysis.csv'
df1 =pd.read_csv(files)
        
df1["DATE"] = pd.to_datetime(df1["DATE"])
df1["DATE"].dt.year
df1.groupby(["BOROUGH"]).sum()
print(df1.groupby(["BOROUGH"]).sum())
df_new=df1.loc[(df1['BOROUGH'] == 'BROOKLYN')]
print(df_new)
#df_new = df1.groupby(["VEHICLE TYPE CODE 1"]).sum()
#print(df_new)
#df_new.plot.pie(x='BOROUGH', y=['NUMBER OF MOTORIST INJURED','NUMBER OF PEDESTRIANS INJURED','NUMBER OF PERSONS INJURED','NUMBER OF CYCLIST INJURED'])
df_new = pd.DataFrame(3 * np.random.rand(4, 1), index=['NUMBER OF MOTORIST INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PERSONS INJURED', 'NUMBER OF CYCLIST INJURED'], columns=['BOROUGH'])
df_new.plot.pie(subplots=True, figsize=(8, 4))

print('here')
plt.show()
# Out:
#                 ZIP CODE      LATITUDE     LONGITUDE  OFF STREET NAME  \
# BOROUGH
# BRONX           97159428  3.794017e+05 -6.864024e+05              NaN
# BROOKLYN       205665368  7.452368e+05 -1.355685e+06              NaN
# MANHATTAN      333315434  1.354763e+06 -2.458443e+06              NaN
# QUEENS         203517219  7.282058e+05 -1.320293e+06              NaN
# STATEN ISLAND   29405416  1.157910e+05 -2.114620e+05              NaN
#
#                NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# BOROUGH
# BRONX                               2999                        11
# BROOKLYN                            5803                        15
# MANHATTAN                           4236                         6
# QUEENS                              5163                         9
# STATEN ISLAND                        685                         2
#
#                NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# BOROUGH
# BRONX                                     52                             4
# BROOKLYN                                  63                             2
# MANHATTAN                                107                             3
# QUEENS                                    47                             1
# STATEN ISLAND                             11                             1
#
#                NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# BOROUGH
# BRONX                                195                         1
# BROOKLYN                             723                         3
# MANHATTAN                           1067                         0
# QUEENS                               371                         3
# STATEN ISLAND                         16                         0
#
#                NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 57     (40.6787832, -73.9109381)            ROCKAWAY AVENUE
# 60     (40.6815143, -73.9041166)            BUSHWICK AVENUE
# 61      (40.662175, -73.9537014)              ROGERS AVENUE
# 62     (40.6854992, -73.9177006)            SARATOGA AVENUE
# 65     (40.6869972, -73.9568428)            FRANKLIN AVENUE
# 66     (40.6103007, -73.9595215)                   AVENUE P
# 68     (40.6412416, -73.9437204)                   AVENUE D
# 70      (40.675297, -73.8726709)              PITKIN AVENUE
# 71     (40.6780095, -73.9413784)            ATLANTIC AVENUE
# ...                          ...                        ...
# 81431  (40.6781158, -73.9217116)            HERKIMER STREET
# 81439  (40.7125234, -73.9383217)               GRAND STREET
# 81441  (40.5983037, -73.9414808)            NOSTRAND AVENUE
# 81447  (40.6863663, -73.9297499)                REID AVENUE
# 81456  (40.6059026, -73.9567944)             EAST 16 STREET
# 81467  (40.6495723, -73.9388628)              SNYDER AVENUE
# 81468  (40.6807335, -73.9745025)                   6 AVENUE
# 81472  (40.6451334, -73.9023131)           ROCKAWAY PARKWAY
# 81475  (40.6960346, -73.9845292)  FLATBUSH AVENUE EXTENSION
# 81478  (40.6434259, -74.0120642)                  53 STREET
# 81491   (40.6605783, -73.990636)                  20 STREET
# 81496  (40.7120573, -73.9661437)               WYTHE AVENUE
# 81499  (40.6753551, -73.9527693)              ROGERS AVENUE
# 81506   (40.645173, -74.0210011)                   2 AVENUE
# 81509   (40.598312, -73.9611853)                   AVENUE U
# 81510  (40.6681684, -73.9772073)                   8 AVENUE
# 81511  (40.7140658, -73.9493728)        METROPOLITAN AVENUE
# 81514  (40.6389656, -73.9425045)              FOSTER AVENUE
# 81518  (40.6508071, -73.9495721)            NOSTRAND AVENUE
# 81527  (40.6436608, -73.9006685)           FLATLANDS AVENUE
# 81531  (40.6026408, -73.9863839)           STILLWELL AVENUE
# 81538  (40.6072584, -74.0026435)                  86 STREET
# 81544  (40.6615914, -73.9968462)                   4 AVENUE
# 81547  (40.6897725, -73.9770989)             DE KALB AVENUE
# 81551  (40.6137031, -73.9382545)               QUENTIN ROAD
# 81555  (40.6679761, -73.9339831)               UNION STREET
# 81561  (40.6943646, -73.9579956)            FRANKLIN AVENUE
# 81569  (40.6949636, -73.9462246)            TOMPKINS AVENUE
# 81581   (40.694578, -73.9561419)             BEDFORD AVENUE
# 81587   (40.6566425, -74.005262)                  34 STREET
#
#            CROSS STREET NAME  OFF STREET NAME         ...          \
# 2             BEDFORD AVENUE              NaN         ...
# 3             EAST 93 STREET              NaN         ...
# 11             OCEAN PARKWAY              NaN         ...
# 14             ALBANY AVENUE              NaN         ...
# 16           SARATOGA AVENUE              NaN         ...
# 20                 65 STREET              NaN         ...
# 22              CROWN STREET              NaN         ...
# 24               DEAN STREET              NaN         ...
# 25           NOSTRAND AVENUE              NaN         ...
# 27     FORT HAMILTON PARKWAY              NaN         ...
# 29             IRVING AVENUE              NaN         ...
# 34            EAST 39 STREET              NaN         ...
# 35          MC DONALD AVENUE              NaN         ...
# 38          TWIN PINES DRIVE              NaN         ...
# 41            EAST 35 STREET              NaN         ...
# 45            CLARENDON ROAD              NaN         ...
# 47       SHEEPSHEAD BAY ROAD              NaN         ...
# 49             COOPER STREET              NaN         ...
# 51           BUSHWICK AVENUE              NaN         ...
# 52                  AVENUE M              NaN         ...
# 54           CLARKSON AVENUE              NaN         ...
# 57             SOMERS STREET              NaN         ...
# 60         VANDERVEER STREET              NaN         ...
# 61           LEFFERTS AVENUE              NaN         ...
# 62             HALSEY STREET              NaN         ...
# 65          LEXINGTON AVENUE              NaN         ...
# 66            EAST 14 STREET              NaN         ...
# 68            EAST 35 STREET              NaN         ...
# 70            DOSCHER STREET              NaN         ...
# 71           KINGSTON AVENUE              NaN         ...
# ...                      ...              ...         ...
# 81431           RALPH AVENUE              NaN         ...
# 81439       WATERBURY STREET              NaN         ...
# 81441               AVENUE V              NaN         ...
# 81447          PUTNAM AVENUE              NaN         ...
# 81456               AVENUE R              NaN         ...
# 81467          ALBANY AVENUE              NaN         ...
# 81468          BERGEN STREET              NaN         ...
# 81472          GLENWOOD ROAD              NaN         ...
# 81475         TILLARY STREET              NaN         ...
# 81478               5 AVENUE              NaN         ...
# 81491               6 AVENUE              NaN         ...
# 81496         SOUTH 5 STREET              NaN         ...
# 81499     SAINT MARKS AVENUE              NaN         ...
# 81506              57 STREET              NaN         ...
# 81509    CONEY ISLAND AVENUE              NaN         ...
# 81510               5 STREET              NaN         ...
# 81511         LORIMER STREET              NaN         ...
# 81514        BROOKLYN AVENUE              NaN         ...
# 81518          CHURCH AVENUE              NaN         ...
# 81527       ROCKAWAY PARKWAY              NaN         ...
# 81531        HIGHLAWN AVENUE              NaN         ...
# 81538              18 AVENUE              NaN         ...
# 81544              23 STREET              NaN         ...
# 81547      FORT GREENE PLACE              NaN         ...
# 81551         EAST 34 STREET              NaN         ...
# 81555     SCHENECTADY AVENUE              NaN         ...
# 81561          MYRTLE AVENUE              NaN         ...
# 81569          VERNON AVENUE              NaN         ...
# 81581          MYRTLE AVENUE              NaN         ...
# 81587               3 AVENUE              NaN         ...
#
#         CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 2               Passenger Distraction                            NaN
# 3      Driver Inattention/Distraction                    Unspecified
# 11     Driver Inattention/Distraction                            NaN
# 14                  Pavement Slippery              Pavement Slippery
# 16            Outside Car Distraction                            NaN
# 20                 Lost Consciousness                            NaN
# 22                 Lost Consciousness                            NaN
# 24                    Fatigued/Drowsy                            NaN
# 25                    Fatigued/Drowsy                            NaN
# 27     Driver Inattention/Distraction                            NaN
# 29              Passenger Distraction                            NaN
# 34                Physical Disability                            NaN
# 35                  Pavement Slippery                            NaN
# 38     Driver Inattention/Distraction                            NaN
# 41     Driver Inattention/Distraction                            NaN
# 45              Failure to Keep Right                            NaN
# 47     Driver Inattention/Distraction                            NaN
# 49      Failure to Yield Right-of-Way  Failure to Yield Right-of-Way
# 51                  Oversized Vehicle                            NaN
# 52            Outside Car Distraction                            NaN
# 54                Physical Disability                            NaN
# 57     Driver Inattention/Distraction                            NaN
# 60      Failure to Yield Right-of-Way                            NaN
# 61                 Lost Consciousness                            NaN
# 81551                            NaN                            NaN
# 81555                            NaN                            NaN
# 81561                            NaN                            NaN
# 81569                            NaN                            NaN
# 81581                            NaN                            NaN
# 81587                            NaN                            NaN
#
#        UNIQUE KEY            VEHICLE TYPE CODE 1  \
# 2         3435821              PASSENGER VEHICLE
# 3         3557624  SPORT UTILITY / STATION WAGON
# 11        3417263              PASSENGER VEHICLE
# 14        3419506              PASSENGER VEHICLE
# 16        3418261              PASSENGER VEHICLE
# 20        3416626              PASSENGER VEHICLE
# 22        3417629              PASSENGER VEHICLE
# 24        3419429              PASSENGER VEHICLE
# 25        3417627              PASSENGER VEHICLE
# 27        3415800              PASSENGER VEHICLE
# 29        3420419              PASSENGER VEHICLE
# 34        3416231              PASSENGER VEHICLE
# 35        3414730              PASSENGER VEHICLE
# 38        3418550              PASSENGER VEHICLE
# 41        3416232              PASSENGER VEHICLE
# 45        3417250              PASSENGER VEHICLE
# 47        3414487              PASSENGER VEHICLE
# 49        3420404              PASSENGER VEHICLE
# 51        3558068  SPORT UTILITY / STATION WAGON
# 52        3557619  SPORT UTILITY / STATION WAGON
# 54        3405086  SPORT UTILITY / STATION WAGON
# 57        3560552              PASSENGER VEHICLE
# 60        3536093              PASSENGER VEHICLE
# 61        3405096  SPORT UTILITY / STATION WAGON
# 62        3418326              PASSENGER VEHICLE
# 65        3419969              PASSENGER VEHICLE
# 66        3417245              PASSENGER VEHICLE
# 68        3416222              PASSENGER VEHICLE
# 70        3418578              PASSENGER VEHICLE
# 71        3419976              PASSENGER VEHICLE
# ...           ...                            ...
# 81431      183846  SPORT UTILITY / STATION WAGON
# 81439      196366              PASSENGER VEHICLE
# 81441      119336                            BUS
# 81447      183665              PASSENGER VEHICLE
# 81456      118871              PASSENGER VEHICLE
# 81467      137250              PASSENGER VEHICLE
# 81468      176261              PASSENGER VEHICLE
# 81472      145115              PASSENGER VEHICLE
# 81475      189046              PASSENGER VEHICLE
# 81478      157264              PASSENGER VEHICLE
# 81491      156842              PASSENGER VEHICLE
# 81496      194734  SPORT UTILITY / STATION WAGON
# 81499      173154              PASSENGER VEHICLE
# 81506      156403         SMALL COM VEH(4 TIRES)
# 81509      116877              PASSENGER VEHICLE
# 81510      176144              PASSENGER VEHICLE
# 81511      194295                           TAXI
# 81514      135635                          OTHER
# 81518      135555              PASSENGER VEHICLE
# 81527      144873              PASSENGER VEHICLE
# 81531      121573         SMALL COM VEH(4 TIRES)
# 81538      121449              PASSENGER VEHICLE
# 81544      158967              PASSENGER VEHICLE
# 81547      193128              PASSENGER VEHICLE
# 81551      128253              PASSENGER VEHICLE
# 81555      155220              PASSENGER VEHICLE
# 81561      180037  SPORT UTILITY / STATION WAGON
# 81569     3291792              PASSENGER VEHICLE
# 81581     3238145              PASSENGER VEHICLE
# 81587      157121                            BUS
#
#                   VEHICLE TYPE CODE 2            VEHICLE TYPE CODE 3  \
# 2                             BICYCLE                            NaN
# 3       SPORT UTILITY / STATION WAGON              PASSENGER VEHICLE
# 11                            BICYCLE                            NaN
# 14                  PASSENGER VEHICLE              PASSENGER VEHICLE
# 16                  PASSENGER VEHICLE                            NaN
# 20     LARGE COM VEH(6 OR MORE TIRES)                            NaN
# 22                  PASSENGER VEHICLE                            NaN
# 24                  PASSENGER VEHICLE                            NaN
# 25                  PASSENGER VEHICLE                            NaN
# 27                                NaN                            NaN
# 29                            BICYCLE                            NaN
# 34                  PASSENGER VEHICLE                            NaN
# 35                  PASSENGER VEHICLE                            NaN
# 38                  PASSENGER VEHICLE                            NaN
# 41                  PASSENGER VEHICLE                            NaN
# 45                  PASSENGER VEHICLE                            NaN
# 47                  PASSENGER VEHICLE                            NaN
# 49                  PASSENGER VEHICLE              PASSENGER VEHICLE
# 51                                NaN                            NaN
# 52                  PASSENGER VEHICLE                            NaN
# 54                  PASSENGER VEHICLE                            NaN
# 57                  PASSENGER VEHICLE                            NaN
# 60      SPORT UTILITY / STATION WAGON                            NaN
# 61                         MOTORCYCLE                            NaN
# 62                  PASSENGER VEHICLE                            NaN
# 65                            BICYCLE                            NaN
# 66                  PASSENGER VEHICLE                            NaN
# 68                  PASSENGER VEHICLE                            NaN
# 70                  PASSENGER VEHICLE                            NaN
# 71                  PASSENGER VEHICLE                            NaN
# ...                               ...                            ...
# 81431   SPORT UTILITY / STATION WAGON                            NaN
# 81439  LARGE COM VEH(6 OR MORE TIRES)                            NaN
# 81441               PASSENGER VEHICLE                            NaN
# 81447               PASSENGER VEHICLE  SPORT UTILITY / STATION WAGON
# 81456               PASSENGER VEHICLE                            NaN
# 81467               PASSENGER VEHICLE                            NaN
# 81468                           OTHER                            NaN
# 81472                  LIVERY VEHICLE                            NaN
# 81475               PASSENGER VEHICLE                            NaN
# 81478               PASSENGER VEHICLE                            NaN
# 81491               PASSENGER VEHICLE                  PICK-UP TRUCK
# 81496               PASSENGER VEHICLE                            NaN
# 81499               PASSENGER VEHICLE                            NaN
# 81506               PASSENGER VEHICLE              PASSENGER VEHICLE
# 81509               PASSENGER VEHICLE                            NaN
# 81510   SPORT UTILITY / STATION WAGON                            VAN
# 81511               PASSENGER VEHICLE                            NaN
# 81514               PASSENGER VEHICLE                            NaN
# 81518               PASSENGER VEHICLE                            NaN
# 81527   SPORT UTILITY / STATION WAGON                            NaN
# 81531               PASSENGER VEHICLE                            NaN
# 81538                             VAN                            NaN
# 81544                         UNKNOWN              PASSENGER VEHICLE
# 81547                         BICYCLE                            NaN
# 81551   SPORT UTILITY / STATION WAGON                            NaN
# 81555   SPORT UTILITY / STATION WAGON                            NaN
# 81561   SPORT UTILITY / STATION WAGON                            NaN
# 81569                         BICYCLE                            NaN
# 81581   SPORT UTILITY / STATION WAGON                            VAN
# 81587          SMALL COM VEH(4 TIRES)                            NaN
#
#       VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 11                    NaN                 NaN
# 14                    NaN                 NaN
# 16                    NaN                 NaN
# 20                    NaN                 NaN
# 22                    NaN                 NaN
# 24                    NaN                 NaN
# 25                    NaN                 NaN
# 27                    NaN                 NaN
# 29                    NaN                 NaN
# 34                    NaN                 NaN
# 35                    NaN                 NaN
# 38                    NaN                 NaN
# 41                    NaN                 NaN
# 45                    NaN                 NaN
# 47                    NaN                 NaN
# 49                    NaN                 NaN
# 51                    NaN                 NaN
# 52                    NaN                 NaN
# 54                    NaN                 NaN
# 57                    NaN                 NaN
# 60                    NaN                 NaN
# 61                    NaN                 NaN
# 62                    NaN                 NaN
# 65                    NaN                 NaN
# 66                    NaN                 NaN
# 68                    NaN                 NaN
# 70                    NaN                 NaN
# 71                    NaN                 NaN
# ...                   ...                 ...
# 81431                 NaN                 NaN
# 81439                 NaN                 NaN
# 81441                 NaN                 NaN
# 81447                 NaN                 NaN
# 81456                 NaN                 NaN
# 81467                 NaN                 NaN
# 81468                 NaN                 NaN
# 81472                 NaN                 NaN
# 81475                 NaN                 NaN
# 81478                 NaN                 NaN
# 81491                 NaN                 NaN
# 81496                 NaN                 NaN
# 81499                 NaN                 NaN
# 81506                 NaN                 NaN
# 81509                 NaN                 NaN
# 81510          MOTORCYCLE                 NaN
# 81511                 NaN                 NaN
# 81514                 NaN                 NaN
# 81518                 NaN                 NaN
# 81527                 NaN                 NaN
# 81531                 NaN                 NaN
# 81538                 NaN                 NaN
# 81544                 NaN                 NaN
# 81547                 NaN                 NaN
# 81551                 NaN                 NaN
# 81555                 NaN                 NaN
# 81561                 NaN                 NaN
# 81569                 NaN                 NaN
# 81581                 NaN                 NaN
# 81587                 NaN                 NaN
#
# [18331 rows x 29 columns]
# here

# %% [markdown]
# # Analysis-5, For the Borough Brooklyn and the year 2016 find the most common occuring contributing factor-1 for accidents and plot the graph for their respective counts

# %%
import matplotlib.pyplot as plt
import glob
import random
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

files='C:/Users/Shailesh Hegde/Desktop/PythonFinal/Accident_analysis.csv'
df1 =pd.read_csv(files)
        
df1["DATE"] = pd.to_datetime(df1["DATE"])
df1["DATE"].dt.year
df1.groupby([df1["DATE"].dt.year]).sum()
#print(df1.groupby([df1["DATE"].dt.year]).sum())
#print(df1.loc[(df1['BOROUGH'] == 'BROOKLYN') & (df1["DATE"].dt.year == 2016)])
df_new=pd.DataFrame({'Count':df1.groupby(df1['VEHICLE TYPE CODE 1']).size()}).reset_index()
print(df_new)
#source = pd.DataFrame(df1)
#source.groupby([df1["CONTRIBUTING FACTOR VEHICLE 1"]]).agg(lambda x:x.value_counts().index['CONTRIBUTING FACTOR VEHICLE 1'])
#df1.plot.bar(x='BOROUGH', y='COUNT')

df_new.plot.bar(x='VEHICLE TYPE CODE 1', y='Count')
print('here')
plt.show()
# Out:
#                VEHICLE TYPE CODE 1  Count
# 0                        AMBULANCE    195
# 1                          BICYCLE    113
# 2                              BUS   1592
# 3                       FIRE TRUCK     45
# 4   LARGE COM VEH(6 OR MORE TIRES)   1447
# 5                   LIVERY VEHICLE   1539
# 6                       MOTORCYCLE    371
# 7                            OTHER   2075
# 8                PASSENGER VEHICLE  44579
# 9                          PEDICAB      4
# 10                   PICK-UP TRUCK   1175
# 11                         SCOOTER     17
# 12          SMALL COM VEH(4 TIRES)   1606
# 13   SPORT UTILITY / STATION WAGON  16854
# 14                            TAXI   6076
# 15                         UNKNOWN   1088
# 16                             VAN   2705
# here
